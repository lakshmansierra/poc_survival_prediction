# %% [markdown]
# # Data Preprocessing Tools

# %% [markdown]
# ## Importing the libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
# Load Excel files
df = pd.read_csv("1_service_now_survival_data/1_service_now_survival_data.csv")

# %%
print(df.columns)
# Out:
# Index(['Asset_Number', 'start', 'stop', 'event', 'Category', 'usage',
#        'temperature', 'load', 'health_bar'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    Asset_Number  start  stop  event  Category      usage  temperature  \
# 0        100080      0    14      0  Security  89.242856    21.072078
# 1        100080     14    17      1  Security  18.028311    52.449810
# 2        100080     17    19      1  Security  56.002279    75.497191
# 3        100080     19    21      0  Security  13.719146    12.130803
# 4        100080     21    25      0  Security  34.996827    10.222960
#
#         load  health_bar
# 0  18.921408   75.926079
# 1  30.837617   46.889084
# 2  14.388191   46.312371
# 3  54.861030  100.000000
# 4  68.653680   43.616789

# %% [markdown]
# ## Correlation

# %%
print(df.isna().sum())
# Out:
# Asset_Number    0
# start           0
# stop            0
# event           0
# Category        0
# usage           0
# temperature     0
# load            0
# health_bar      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Drop non-numeric and identifier columns (like 'Asset_Number', 'start', 'stop', 'event' can be kept for inspection if needed)
numeric_df = df.drop(columns=["Asset_Number", "Category"])

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Export Updated Excel

# %%
# Create the folder if it doesn't exist
os.makedirs("2_service_now_lifelines_updated_data", exist_ok=True)

# Save the Excel file inside the folder
df.to_csv("2_service_now_lifelines_updated_data/2_service_now_lifelines_updated_data.csv", index=False)
